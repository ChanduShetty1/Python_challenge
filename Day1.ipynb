# %% [markdown]
# # Python Programming
# - ***Easy to Learn***: Syntax resembles plain English.
# - **Interpreted Language**: Executes code line-by-line for easier debugging.
# - **Highly Readable**: Uses clean layout and indentation.
#
# #  Where Python Used Widely
# 1. Web devlopment
# 2. Data analysis
# 3. Machin learning
# 4. Gen AI / Computer vision
# 5. Automation
# 6. Deep learning
# 7. Database configuration
# 8. Data visulization

# %% [markdown]
# ## variables :
# - Python variables are reserved memory.
# - till the variables are assigned with any other value.
# - It is **case sensitive**

# %%
a = 55 #Example for case sensitive
A = 45
print(a)
print(A)
# Out:
# 55
# 45

# %% [markdown]
# ## Variable Overwriting :

# %%
p = 10
p = p + 10
print(p)
# Out:
# 20

# %% [markdown]
# ### Multiple Variable Assignment:

# %%
a,b,c = 3,4,5 # multiple variable with multiple value
print(a,b,c)
# Out:
# 3 4 5

# %%
a = b = c = d = 44 # multiple variable with single value
print(a)
print(b)
print(c)
print(d)
# Out:
# 44
# 44
# 44
# 44
